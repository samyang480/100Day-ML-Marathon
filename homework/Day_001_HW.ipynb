# %% [markdown]
# Hw1 Black Friday
# 1.選的這組資料為何重要？
#     此組資料統計了在該零售商購物之顧客資料，希望找出對於不同產品，消費者的購買行為是否有所不同
# 2.資料從何而來？
#     The dataset comes from a competition hosted by Analytics Vidhya
# 3.搜集這類型的資料型態為何？
#     結構化資料
# 4.這組資料想解決的問題如何評估？
#     使用 MSE 查看各產品與其他值的變動關係

# %% [markdown]
# Hw2
# 1. 核心問題？
#     提升業績：提升載客量以及每位客人的搭乘長度
# 2. 資料從何而來？
#     根據車隊載客資料，統計上車點、下車點、搭乘時間等
# 3. 搜集而來的資料型態？
#     包含結構化與非結構化（地點）等
# 4. 如何評估？
#     使用 MSE 查看提升特定地點的車隊數量是否提升載客量

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_squared_error(y, yp):
    """
    請完成這個 Function 後往下執行
    """
    mse = MSE = sum((y-yp)*(y-yp))/len(y)
    return mse

MSE = mean_squared_error(y, y_hat)
print("The Mean Squared error is %.3f" % (MSE))
# Out:
# The Mean Squared error is 211.913

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-5eedadaa368e> in <module>()
#       1 # 執行 Function, 確認有沒有正常執行
#       2 MSE = mean_squared_error(y, y_hat)
# ----> 3 MAE = mean_absolute_error(y, y_hat)
#       4 print("The Mean squared error is %.3f" % (MSE))
#       5 print("The Mean absolute error is %.3f" % (MAE))
#
# NameError: name 'mean_absolute_error' is not defined
